# %% [markdown]
# vowels in the string

# %% [markdown]
# "education" → 5

# %%
def vowelspresent(s):
	count=0
	for i in s:
		if i in ['i','e','a','o','u']:
			count+=1
	return count
vowelspresent("howareyou")
# Out:
# 5
