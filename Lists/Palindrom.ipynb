# %%
def check_palindrome(ls):
		return ls == ls[::-1]
print(check_palindrome(['r','a','c','e','c','a','r']))
# Out:
# True

# %%
def check_palindrome(s):
		return s==s[::-1]
print(check_palindrome("madam"))
# Out:
# True
