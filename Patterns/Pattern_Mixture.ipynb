# %%
n=5 
for i in range(1,n+1):
    {
        print('#' * (n-i+1)+ '*' * i)
		}
# Out:
# #####*
# ####**
# ###***
# ##****
# #*****

# %%
def pattern_mixture(n):
    for i in range(n+1, 0, -1):
        {
          print('#' * (n-i+2) + '*' * i)
				}
pattern_mixture(4)
# Out:
# #*****
# ##****
# ###***
# ####**
# #####*
