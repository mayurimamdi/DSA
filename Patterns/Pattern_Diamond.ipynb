# %%
def pattern_mountain(n):
    for i in range(1,n+1):
        {
            print(' ' * (n-i) + '*' * i + '*' * (i-1))
				}
pattern_mountain(5) 
def pattern_dia(n):
		for i in range(n+1, 0, -1):
				print(' ' * (n-i+1) + '*' * i + '*' * (i-1))
pattern_dia(4)
# Out:
#     *
#    ***
#   *****
#  *******
# *********
# *********
#  *******
#   *****
#    ***
#     *
