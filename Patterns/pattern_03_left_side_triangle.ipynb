# %%
n=5
for i in range(1, n+1):
	{
		print(' ' * (n-i) + '*' * i)
	}
# Out:
#     *
#    **
#   ***
#  ****
# *****

# %%
n=4
for i in range(n+1, 0, -1):
    { 
        print(' '* (n-i+1) + '*' * i)
		}
# Out:
# *****
#  ****
#   ***
#    **
#     *
