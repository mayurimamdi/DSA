# %%
def pattern_mountain(n):
    for i in range(1,n+1):
        {
            print(' ' * (n-i) + '* ' * i)
				}
pattern_mountain(5)
# Out:
#     *
#    * *
#   * * *
#  * * * *
# * * * * *

# %%
def pattern_mountain(n):
    for i in range(1,n+1):
        {
            print(' ' * (n-i) + '*' * i + '*' * (i-1))
				}
pattern_mountain(5)
# Out:
#     *
#    ***
#   *****
#  *******
# *********
